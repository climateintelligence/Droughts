# %% [markdown]
# # Preliminaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import sys
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

sys.path.append("/Users/paolo/Documents/methods/CMI_FS")
from feature_selection import forwardFeatureSelection

sys.path.append("/Users/paolo/Documents/methods/LinCFA")
from LinCFA import LinCFA

sys.path.append("/Users/paolo/Documents/Droughts/Paolo/regression_LinCFA")
from aux import standardize,unfold_dataset,compute_r2,prepare_target,prepare_features,aggregate_unfolded_data,FS_with_linearWrapper,compare_methods,standardize

# %%
def plot_cells(output,selected_colnames, xmin=9, xmax=11, ymin=44, ymax=45.5):
    x = []
    y = []
    colors = cm.rainbow(np.linspace(0,1,len(output)))
    np.random.shuffle(colors)
    fig, ax = plt.subplots(2)
    ax[0].set_xlim(xmin,xmax)
    ax[1].set_xlim(xmin,xmax)
    ax[0].set_ylim(ymin,ymax)
    ax[1].set_ylim(ymin,ymax)
    for i in range(len(output)): 
        #print(len(output[i]))
        x = []
        y = []
        
        for datum in output[i]:
            x.append(float(datum.split('_')[1]))
            y.append(float(datum.split('_')[2]))
        ax[0].scatter(x,y,color=colors[i])
    
    x = []
    y = []
    col = cm.rainbow(np.linspace(0,1,len(selected_colnames)))
    for i in range(len(selected_colnames)): 
        idx = int(selected_colnames[i].split('_')[-1])
        for datum in output[idx]:
            x.append(float(datum.split('_')[1]))
            y.append(float(datum.split('_')[2]))
        ax[1].scatter(x,y,color=col[i])

# %% [markdown]
# # Target

# %%
target_df = pd.read_csv('/Users/paolo/Documents/OneDrive - Politecnico di Milano/droughts/csv_VHI/Emiliani2.csv')
target_df = target_df.rename({'Unnamed: 0':'date'},axis=1)
target_df
### va ancora standardizzato
# Out:
#            date      mean  median  year  week
# 0    2001-01-05  0.214281    0.00  2001     1
# 1    2001-01-13  0.484737    0.52  2001     2
# 2    2001-01-21  0.466071    0.47  2001     3
# 3    2001-01-29  0.417470    0.44  2001     5
# 4    2001-02-06  0.492202    0.53  2001     6
# ..          ...       ...     ...   ...   ...
# 983  2022-07-18  0.137749    0.11  2022    29
# 984  2022-07-26  0.119336    0.08  2022    30
# 985  2022-08-03  0.175099    0.15  2022    31
# 986  2022-08-11  0.227789    0.19  2022    32
# 987  2022-08-19  0.365810    0.38  2022    33
#
# [988 rows x 5 columns]

# %% [markdown]
# # Features of entire basins

# %% [markdown]
# ## Emiliani2

# %%
path='/Users/paolo/Documents/OneDrive - Politecnico di Milano/droughts/features/csv_mean/features_with_aggregations.csv'

df_emil = pd.read_csv(path)
df_emil = df_emil.loc[:,['date','cyclostationary_mean_Emiliani2_rr',
                        'cyclostationary_mean_Emiliani2_rr_1w',
                        'cyclostationary_mean_Emiliani2_rr_4w',
                        'cyclostationary_mean_Emiliani2_rr_8w',
                        'cyclostationary_mean_Emiliani2_rr_12w',
                        'cyclostationary_mean_Emiliani2_rr_16w',
                        'cyclostationary_mean_Emiliani2_rr_24w',
                        'cyclostationary_mean_Emiliani2_tg',
                        'cyclostationary_mean_Emiliani2_tg_1w',
                        'cyclostationary_mean_Emiliani2_tg_4w',
                        'cyclostationary_mean_Emiliani2_tg_8w',
                        'cyclostationary_mean_Emiliani2_tg_12w',
                        'cyclostationary_mean_Emiliani2_tg_16w',
                        'cyclostationary_mean_Emiliani2_tg_24w']]

full_df_emil = df_emil.set_index('date').join(target_df.set_index('date').loc[:,'mean'],on='date')
full_df_emil = full_df_emil
full_df_emil = full_df_emil.sample(frac=1,random_state=42).reset_index().iloc[:,1:]
full_df_emil = (full_df_emil-full_df_emil[0:587].mean())/full_df_emil[0:587].std()
full_df_emil = full_df_emil.rename(columns={'mean':'mean_std'})
full_df_emil
# Out:
#      cyclostationary_mean_Emiliani2_rr  cyclostationary_mean_Emiliani2_rr_1w  \
# 0                             0.524302                              0.157558
# 1                            -1.161748                             -1.682053
# 2                             1.215539                              0.554803
# 3                             0.376869                             -0.295749
# 4                            -0.417147                             -0.257116
# ..                                 ...                                   ...
# 976                          -0.916202                             -1.244376
# 977                          -1.889644                             -0.997692
# 978                          -0.111602                             -0.605914
# 979                          -0.175273                             -0.285777
# 980                          -0.947711                             -1.127953
#
#      cyclostationary_mean_Emiliani2_rr_4w  \
# 0                                1.093683
# 1                                0.126582
# 2                                0.360345
# 3                               -0.163961
# 4                                0.054241
# ..                                    ...
# 976                             -0.650640
# 977                             -2.450834
# 978                             -0.488927
# 979                              1.096019
# 980                             -1.426806
#
#      cyclostationary_mean_Emiliani2_rr_8w  \
# 0                                1.104316
# 1                               -0.657991
# 2                                0.283570
# 3                                0.800103
# 4                                0.342975
# ..                                    ...
# 976                             -1.203343
# 977                             -2.071970
# 978                             -0.657819
# 979                              0.508300
# 980                             -1.606052
#
#      cyclostationary_mean_Emiliani2_rr_12w  \
# 0                                 0.939520
# 1                                -0.787927
# 2                                 1.063649
# 3                                 1.439970
# 4                                -0.333173
# ..                                     ...
# 976                              -1.461452
# 977                              -1.172678
# 978                              -0.451612
# 979                               0.749960
# 980                              -0.873737
#
#      cyclostationary_mean_Emiliani2_rr_16w  \
# 0                                 1.369578
# 1                                -0.678756
# 2                                 0.692451
# 3                                 2.091421
# 4                                -0.374726
# ..                                     ...
# 976                              -0.885803
# 977                              -0.487388
# 978                              -0.220726
# 979                               0.721446
# 980                               0.246161
#
#      cyclostationary_mean_Emiliani2_rr_24w  cyclostationary_mean_Emiliani2_tg  \
# 0                                 0.325633                           0.186608
# 1                                -0.225455                          -1.206555
# 2                                 0.032648                           0.517479
# 3                                 2.096346                          -2.421726
# 4                                -1.400288                          -0.485484
# ..                                     ...                                ...
# 976                              -0.419054                           0.521754
# 977                              -0.789769                           0.646330
# 978                               0.840648                           0.672917
# 979                               0.952282                           1.080765
# 980                              -0.194420                           0.259102
#
#      cyclostationary_mean_Emiliani2_tg_1w  \
# 0                                0.149698
# 1                               -1.211424
# 2                                0.470635
# 3                               -0.806943
# 4                               -0.389354
# ..                                    ...
# 976                              0.334061
# 977                              0.984838
# 978                              1.636813
# 979                              1.064468
# 980                             -0.571525
#
#      cyclostationary_mean_Emiliani2_tg_4w  \
# 0                               -0.535308
# 1                               -1.469446
# 2                                0.110337
# 3                               -1.636368
# 4                               -0.420201
# ..                                    ...
# 976                             -0.732691
# 977                              0.496367
# 978                              2.167862
# 979                              0.027597
# 980                             -0.265390
#
#      cyclostationary_mean_Emiliani2_tg_8w  \
# 0                               -1.505113
# 1                               -0.488423
# 2                                0.551733
# 3                               -1.338809
# 4                               -1.161823
# ..                                    ...
# 976                             -0.731812
# 977                              0.647662
# 978                              2.284608
# 979                             -0.128616
# 980                             -0.855241
#
#      cyclostationary_mean_Emiliani2_tg_12w  \
# 0                                -0.479228
# 1                                 0.292782
# 2                                -0.273130
# 3                                -1.508013
# 4                                -0.622394
# ..                                     ...
# 976                              -1.085905
# 977                               0.253260
# 978                               2.232513
# 979                              -0.031113
# 980                              -0.396932
#
#      cyclostationary_mean_Emiliani2_tg_16w  \
# 0                                -0.358055
# 1                                -0.294743
# 2                                -0.077799
# 3                                -1.832927
# 4                                -0.149486
# ..                                     ...
# 976                              -0.688233
# 977                              -0.131624
# 978                               2.487259
# 979                              -0.367089
# 980                               0.188987
#
#      cyclostationary_mean_Emiliani2_tg_24w  mean_std
# 0                                -0.508335  0.463787
# 1                                -0.103686 -0.479136
# 2                                 0.685891 -0.067946
# 3                                -1.522427 -0.727431
# 4                                -0.995921  0.248559
# ..                                     ...       ...
# 976                              -0.154488 -1.479312
# 977                              -0.078438 -0.538063
# 978                               1.224023  0.393759
# 979                              -0.638149  0.671123
# 980                              -0.210166  0.101909
#
# [981 rows x 15 columns]

# %%
### wrapper FS, linear regression

selected_colnames = FS_with_linearWrapper(full_df_emil.iloc[0:784,:-1], full_df_emil.iloc[0:587], full_df_emil.iloc[587:784], max_feat=12 , val_len=197)
compare_methods(full_df_emil.iloc[0:784,:-1], full_df_emil.iloc[784:,:-1], full_df_emil.iloc[0:784], full_df_emil.iloc[784:], selected_colnames)
# Out:
# actual training score: 0.17381104087702315
# actual validation score: 0.1598897316945469, number of remaining columns: 12
#
# actual training score: 0.1765820656802578
# actual validation score: 0.17863144103703354, number of remaining columns: 11
#
# actual training score: 0.1938121549106997
# actual validation score: 0.1902243973995006, number of remaining columns: 10
#
# actual training score: 0.1943787825690343
# actual validation score: 0.18954114986997395, number of remaining columns: 9
#
# actual training score: 0.19686083364675722
# actual validation score: 0.18780475315272926, number of remaining columns: 8
#
# actual training score: 0.19686366346108541
# actual validation score: 0.18761812788593735, number of remaining columns: 7
#
# actual training score: 0.1968676040447226
# actual validation score: 0.18724922023813684, number of remaining columns: 6
#
# actual training score: 0.20519532516024674
# actual validation score: 0.18110113215657142, number of remaining columns: 5
#
# actual training score: 0.2063022024488036
# actual validation score: 0.17410452068208393, number of remaining columns: 4
#
# actual training score: 0.20868437627690817
# actual validation score: 0.16587457524547655, number of remaining columns: 3
#
# actual training score: 0.2124918342431178
# actual validation score: 0.15575080134370456, number of remaining columns: 2
#
# actual training score: 0.22145353055604344
# actual validation score: 0.13476224672027382, number of remaining columns: 1
#
#
#
# selected columns: ['cyclostationary_mean_Emiliani2_tg', 'cyclostationary_mean_Emiliani2_rr_8w', 'cyclostationary_mean_Emiliani2_tg_24w', 'cyclostationary_mean_Emiliani2_tg_1w'],
#
# validation score: 0.1902243973995006,
#
# number of selected features: 4
# Full aggregate regression train score: 0.2071472957347753, test score: 0.23209352502439007
# Aggregate regression train score with FS: 0.1941500963100261, test score: 0.20468611705341355

# %%
### CMI FS, linear regression

res = {
    "delta" : [], # list with all deltas
    "numSelected" : [], #
    "selectedFeatures" : [] 
}

res['selectedFeatures'] = forwardFeatureSelection(10,np.array(full_df_emil.iloc[0:784,:-1]),np.array(full_df_emil.iloc[0:784,-1]),res,10,1)
selectedFeatures='selectedFeatures'
print(f'\n{res[selectedFeatures]}\n')
selected_colnames = full_df_emil.iloc[0:784,:-1].columns[res['selectedFeatures']]
compare_methods(full_df_emil.iloc[0:784,:-1], full_df_emil.iloc[784:,:-1], full_df_emil.iloc[0:784], full_df_emil.iloc[784:], selected_colnames)
# Out:
# ----- MI Scores -----
# [(8, 0.10677308044457821), (7, 0.07998379304570234), (4, 0.07568326651673606), (2, 0.0707690093560488), (0, 0.06681270116458896), (3, 0.06611643096346552), (1, 0.058977132394013), (5, 0.05272266190975899), (9, 0.05071543878043399), (6, 0.024314421910493933), (11, 0.022846847681457682), (10, 0.02160972710057967), (13, 0.02026627050130758), (12, 0.015021149115334188)]
# Best MI score: 0.10677308044457821
# Adding first best original feature: 8
# CMI: 0.01904473341615727
# CMI: 0.02758615011876482
# CMI: 0.044616852132317905
# CMI: 0.06624167323971823
# CMI: 0.04575812555935198
# CMI: 0.029118158141289138
# CMI: 0.01151758323873553
# CMI: 0.004205476190006691
# CMI: 0.0029593693038672403
# CMI: 0.0163007354102217
# CMI: 0.0022666848944239704
# Highest CMI score: 0.06624167323971823
# Adding original feature: 3
# CMI: 0.007889197252995112
# CMI: 0.008674231438313945
# CMI: 0.01725593486305943
# CMI: 0.008223682412345834
# CMI: 0.0022632118889105157
# CMI: 0.032793339874439636
# CMI: 0.03046836772971484
# CMI: 0.03194031456537147
# CMI: 0.014215508549285966
# CMI: 0.020720317010552824
# Highest CMI score: 0.032793339874439636
# Adding original feature: 9
# Highest CMI score: -0.0016371078827330243
#
# [8, 3, 9]
#
# Full aggregate regression train score: 0.2071472957347753, test score: 0.23209352502439007
# Aggregate regression train score with FS: 0.17822923483219721, test score: 0.18313701380954972

# %% [markdown]
# ## All

# %%
path='/Users/paolo/Documents/OneDrive - Politecnico di Milano/droughts/features/csv_mean/features_with_aggregations.csv'

df = pd.read_csv(path)

full_df = df.set_index('date').join(target_df.set_index('date').loc[:,'mean'],on='date')
full_df = full_df
full_df = full_df.sample(frac=1,random_state=42).reset_index().iloc[:,1:]
full_df = (full_df-full_df[0:587].mean())/full_df[0:587].std()
full_df = full_df.rename(columns={'mean':'mean_std'})
full_df
# Out:
#      cyclostationary_mean_Adda_tg  cyclostationary_mean_Dora_tg  \
# 0                        0.006824                      0.080891
# 1                       -0.357125                      0.293655
# 2                       -0.085151                     -0.383801
# 3                       -2.366818                     -2.368039
# 4                       -0.356840                     -0.020777
# ..                            ...                           ...
# 976                      0.332998                      0.296616
# 977                      1.080595                      1.477705
# 978                     -0.182650                     -0.185003
# 979                      1.626584                      1.546044
# 980                      0.601854                      0.828894
#
#      cyclostationary_mean_Emiliani1_tg  cyclostationary_mean_Piemonte_Sud_tg  \
# 0                             0.596731                             -0.160059
# 1                            -1.610214                             -0.147668
# 2                             1.129743                              0.279558
# 3                            -2.542257                             -2.373116
# 4                            -0.521238                             -0.439547
# ..                                 ...                                   ...
# 976                           0.746974                              0.382502
# 977                           0.386989                              1.326431
# 978                           0.111882                              0.643581
# 979                           0.968828                              1.266546
# 980                           0.227927                              0.291652
#
#      cyclostationary_mean_Piemonte_Nord_tg  \
# 0                                 0.137428
# 1                                -0.496976
# 2                                 0.274454
# 3                                -2.270612
# 4                                -0.204214
# ..                                     ...
# 976                               0.279021
# 977                               1.368809
# 978                               0.391294
# 979                               1.420689
# 980                               0.489018
#
#      cyclostationary_mean_Oglio_Iseo_tg  cyclostationary_mean_Ticino_tg  \
# 0                              0.095889                       -0.274535
# 1                             -0.987415                       -0.048956
# 2                              0.281178                       -0.054993
# 3                             -2.448647                       -2.375566
# 4                             -0.343638                       -0.176151
# ..                                  ...                             ...
# 976                            0.459944                        0.301819
# 977                            1.000030                        1.295577
# 978                            0.029811                       -0.129098
# 979                            1.686314                        1.750038
# 980                            0.448302                        0.685557
#
#      cyclostationary_mean_Garda_Mincio_tg  \
# 0                                0.526869
# 1                               -1.448620
# 2                                0.564053
# 3                               -2.367601
# 4                               -0.328871
# ..                                    ...
# 976                              0.387113
# 977                              0.799559
# 978                              0.072135
# 979                              1.248080
# 980                              0.285804
#
#      cyclostationary_mean_Lambro_Olona_tg  cyclostationary_mean_Emiliani2_tg  \
# 0                                0.054171                           0.186608
# 1                               -1.558525                          -1.206555
# 2                                0.673981                           0.517479
# 3                               -2.179528                          -2.421726
# 4                               -0.383372                          -0.485484
# ..                                    ...                                ...
# 976                              0.259188                           0.521754
# 977                              1.067010                           0.646330
# 978                              0.531165                           0.672917
# 979                              1.184139                           1.080765
# 980                              0.167071                           0.259102
#
#      ...  cyclostationary_mean_Lambro_Olona_rr_12w  \
# 0    ...                                  0.727145
# 1    ...                                 -0.415499
# 2    ...                                  0.830621
# 3    ...                                  1.875842
# 4    ...                                  0.843995
# ..   ...                                       ...
# 976  ...                                 -1.660833
# 977  ...                                 -0.823433
# 978  ...                                  1.375164
# 979  ...                                  0.242012
# 980  ...                                 -1.104211
#
#      cyclostationary_mean_Lambro_Olona_rr_16w  \
# 0                                    0.970206
# 1                                   -0.141138
# 2                                    0.594429
# 3                                    1.904663
# 4                                    1.310773
# ..                                        ...
# 976                                 -1.473781
# 977                                 -0.516489
# 978                                  0.998210
# 979                                  0.414568
# 980                                  0.701030
#
#      cyclostationary_mean_Lambro_Olona_rr_24w  \
# 0                                   -0.144642
# 1                                    0.380466
# 2                                   -0.104474
# 3                                    1.314706
# 4                                    0.209057
# ..                                        ...
# 976                                 -0.277854
# 977                                 -1.037792
# 978                                  0.870613
# 979                                  0.494937
# 980                                  0.140543
#
#      cyclostationary_mean_Emiliani2_rr_1w  \
# 0                                0.157558
# 1                               -1.682053
# 2                                0.554803
# 3                               -0.295749
# 4                               -0.257116
# ..                                    ...
# 976                             -1.244376
# 977                             -0.997692
# 978                             -0.605914
# 979                             -0.285777
# 980                             -1.127953
#
#      cyclostationary_mean_Emiliani2_rr_4w  \
# 0                                1.093683
# 1                                0.126582
# 2                                0.360345
# 3                               -0.163961
# 4                                0.054241
# ..                                    ...
# 976                             -0.650640
# 977                             -2.450834
# 978                             -0.488927
# 979                              1.096019
# 980                             -1.426806
#
#      cyclostationary_mean_Emiliani2_rr_8w  \
# 0                                1.104316
# 1                               -0.657991
# 2                                0.283570
# 3                                0.800103
# 4                                0.342975
# ..                                    ...
# 976                             -1.203343
# 977                             -2.071970
# 978                             -0.657819
# 979                              0.508300
# 980                             -1.606052
#
#      cyclostationary_mean_Emiliani2_rr_12w  \
# 0                                 0.939520
# 1                                -0.787927
# 2                                 1.063649
# 3                                 1.439970
# 4                                -0.333173
# ..                                     ...
# 976                              -1.461452
# 977                              -1.172678
# 978                              -0.451612
# 979                               0.749960
# 980                              -0.873737
#
#      cyclostationary_mean_Emiliani2_rr_16w  \
# 0                                 1.369578
# 1                                -0.678756
# 2                                 0.692451
# 3                                 2.091421
# 4                                -0.374726
# ..                                     ...
# 976                              -0.885803
# 977                              -0.487388
# 978                              -0.220726
# 979                               0.721446
# 980                               0.246161
#
#      cyclostationary_mean_Emiliani2_rr_24w  mean_std
# 0                                 0.325633  0.463787
# 1                                -0.225455 -0.479136
# 2                                 0.032648 -0.067946
# 3                                 2.096346 -0.727431
# 4                                -1.400288  0.248559
# ..                                     ...       ...
# 976                              -0.419054 -1.479312
# 977                              -0.789769 -0.538063
# 978                               0.840648  0.393759
# 979                               0.952282  0.671123
# 980                              -0.194420  0.101909
#
# [981 rows x 141 columns]

# %%
### wrapper FS, linear regression

selected_colnames = FS_with_linearWrapper(full_df.iloc[0:784,:-1], full_df.iloc[0:587], full_df.iloc[587:784], max_feat=50 , val_len=197)
compare_methods(full_df.iloc[0:784,:-1], full_df.iloc[784:,:-1], full_df.iloc[0:784], full_df.iloc[784:], selected_colnames)
# Out:
# actual training score: 0.19102362878485557
# actual validation score: 0.19350904777114175, number of remaining columns: 138
#
# actual training score: 0.1977056464882181
# actual validation score: 0.22179924614012436, number of remaining columns: 137
#
# actual training score: 0.20807516110200608
# actual validation score: 0.2396065074085464, number of remaining columns: 136
#
# actual training score: 0.2157560108637726
# actual validation score: 0.24849183370483519, number of remaining columns: 135
#
# actual training score: 0.22071948298632627
# actual validation score: 0.25344508952474243, number of remaining columns: 134
#
# actual training score: 0.22180723272519887
# actual validation score: 0.2576345967559206, number of remaining columns: 133
#
# actual training score: 0.23367638101787724
# actual validation score: 0.26621563074742294, number of remaining columns: 132
#
# actual training score: 0.2351339875533136
# actual validation score: 0.27097192220775324, number of remaining columns: 131
#
# actual training score: 0.23639811961582702
# actual validation score: 0.2764641155092237, number of remaining columns: 130
#
# actual training score: 0.23682984161572607
# actual validation score: 0.27908678172849855, number of remaining columns: 129
#
# actual training score: 0.24972657315324864
# actual validation score: 0.2855697143981808, number of remaining columns: 128
#
# actual training score: 0.2507514162844995
# actual validation score: 0.2902073380471446, number of remaining columns: 127
#
# actual training score: 0.2578084133304557
# actual validation score: 0.29473210268799155, number of remaining columns: 126
#
# actual training score: 0.2619265329944659
# actual validation score: 0.30037778928671366, number of remaining columns: 125
#
# actual training score: 0.2640172846706089
# actual validation score: 0.30345168983542037, number of remaining columns: 124
#
# actual training score: 0.2644084613752399
# actual validation score: 0.30500422751492107, number of remaining columns: 123
#
# actual training score: 0.26564753270785835
# actual validation score: 0.308488135494025, number of remaining columns: 122
#
# actual training score: 0.2672008053298467
# actual validation score: 0.31015519859207463, number of remaining columns: 121
#
# actual training score: 0.26743263615344526
# actual validation score: 0.3117666468085277, number of remaining columns: 120
#
# actual training score: 0.2692263411636302
# actual validation score: 0.31593112805118995, number of remaining columns: 119
#
# actual training score: 0.26997708856177693
# actual validation score: 0.31800832143329494, number of remaining columns: 118
#
# actual training score: 0.27039289053397786
# actual validation score: 0.3194499589754489, number of remaining columns: 117
#
# actual training score: 0.2764904581366834
# actual validation score: 0.3251216063796659, number of remaining columns: 116
#
# actual training score: 0.27866944450470443
# actual validation score: 0.3272805459068855, number of remaining columns: 115
#
# actual training score: 0.2796245779117079
# actual validation score: 0.329066446553818, number of remaining columns: 114
#
# actual training score: 0.2801266403669226
# actual validation score: 0.3308795458208089, number of remaining columns: 113
#
# actual training score: 0.28287690746140426
# actual validation score: 0.33246482262564436, number of remaining columns: 112
#
# actual training score: 0.2842064666364106
# actual validation score: 0.3333293818575259, number of remaining columns: 111
#
# actual training score: 0.2842528405821255
# actual validation score: 0.3331767027351802, number of remaining columns: 110
#
# actual training score: 0.28437584266383686
# actual validation score: 0.33276435430015505, number of remaining columns: 109
#
# actual training score: 0.2852331984890588
# actual validation score: 0.33272990873626396, number of remaining columns: 108
#
# actual training score: 0.28526869186722137
# actual validation score: 0.3324139573277064, number of remaining columns: 107
#
# actual training score: 0.2855392120339745
# actual validation score: 0.33216142323227904, number of remaining columns: 106
#
# actual training score: 0.28559382652131626
# actual validation score: 0.3315678263343982, number of remaining columns: 105
#
# actual training score: 0.2855938325740027
# actual validation score: 0.33157781541221376, number of remaining columns: 104
#
# actual training score: 0.2966360664957579
# actual validation score: 0.33066074210884155, number of remaining columns: 103
#
# actual training score: 0.29675714277649845
# actual validation score: 0.33063987631659497, number of remaining columns: 102
#
# actual training score: 0.29697986464658954
# actual validation score: 0.3301061700968779, number of remaining columns: 101
#
# actual training score: 0.2974355566382736
# actual validation score: 0.3282890538334884, number of remaining columns: 100
#
# actual training score: 0.29771848608298157
# actual validation score: 0.32729546926888486, number of remaining columns: 99
#
# actual training score: 0.29943702827824714
# actual validation score: 0.32627381619674656, number of remaining columns: 98
#
# actual training score: 0.30034547071035267
# actual validation score: 0.323763865525561, number of remaining columns: 97
#
# actual training score: 0.30482178859548625
# actual validation score: 0.3246153676530916, number of remaining columns: 96
#
# actual training score: 0.30505012417753774
# actual validation score: 0.3225451140426474, number of remaining columns: 95
#
# actual training score: 0.30547663610488796
# actual validation score: 0.3207365692902291, number of remaining columns: 94
#
# actual training score: 0.3063825417938669
# actual validation score: 0.3184700437298986, number of remaining columns: 93
#
# actual training score: 0.3064633680313429
# actual validation score: 0.3171069342213929, number of remaining columns: 92
#
# actual training score: 0.31012765859823177
# actual validation score: 0.31494445840572916, number of remaining columns: 91
#
# actual training score: 0.3119758124653005
# actual validation score: 0.313677934656292, number of remaining columns: 90
#
# actual training score: 0.31429487526888045
# actual validation score: 0.30997081635117585, number of remaining columns: 89
#
#
#
# selected columns: ['cyclostationary_mean_Emiliani1_tg', 'cyclostationary_mean_Emiliani1_rr_4w', 'cyclostationary_mean_Oglio_Iseo_tg_24w', 'cyclostationary_mean_Dora_rr_24w', 'cyclostationary_mean_Emiliani1_tg_1w', 'cyclostationary_mean_Oglio_Iseo_tg_4w', 'cyclostationary_mean_Ticino_rr_24w', 'cyclostationary_mean_Lambro_Olona_rr_8w', 'cyclostationary_mean_Dora_rr_12w', 'cyclostationary_mean_Emiliani2_rr_4w', 'cyclostationary_mean_Piemonte_Nord_rr_4w', 'cyclostationary_mean_Lambro_Olona_rr_12w', 'cyclostationary_mean_Piemonte_Nord_rr_16w', 'cyclostationary_mean_Lambro_Olona_rr_16w', 'cyclostationary_mean_Ticino_rr_8w', 'cyclostationary_mean_Garda_Mincio_tg_4w', 'cyclostationary_mean_Ticino_rr_12w', 'cyclostationary_mean_Ticino_rr_16w', 'cyclostationary_mean_Dora_rr_8w', 'cyclostationary_mean_Adda_rr_16w', 'cyclostationary_mean_Adda_rr_24w', 'cyclostationary_mean_Adda_tg_24w', 'cyclostationary_mean_Emiliani2_tg_24w', 'cyclostationary_mean_Lambro_Olona_tg_24w', 'cyclostationary_mean_Emiliani2_tg_4w', 'cyclostationary_mean_Emiliani1_rr_16w', 'cyclostationary_mean_Lambro_Olona_tg_8w', 'cyclostationary_mean_Emiliani2_tg_8w', 'cyclostationary_mean_Garda_Mincio_tg_24w'],
#
# validation score: 0.3333293818575259,
#
# number of selected features: 29
# Full aggregate regression train score: 0.4797963011685116, test score: 0.25922974424038114
# Aggregate regression train score with FS: 0.29821692275343215, test score: 0.2966058843181447

# %%
### CMI FS, linear regression

res = {
    "delta" : [], # list with all deltas
    "numSelected" : [], #
    "selectedFeatures" : [] 
}

res['selectedFeatures'] = forwardFeatureSelection(10,np.array(full_df.iloc[0:784,:-1]),np.array(full_df.iloc[0:784,-1]),res,10,1)
selectedFeatures='selectedFeatures'
print(f'\n{res[selectedFeatures]}\n')
# CMI: 0.004939077625218696
# CMI: 0.0014848479603828124
# CMI: 0.007767851423785749
# CMI: 0.024842462259006076
# CMI: 0.002098044611283434
# CMI: 0.00906431302746799
# CMI: 0.0065529232610379295
# CMI: 0.00497299325222203
# CMI: 0.009581288590424536
# CMI: 0.005419492790680602
# CMI: 0.005952711438683922
# CMI: 0.002098464546312212
# CMI: 0.014675241973275133
# CMI: 0.004210260614094075
# CMI: 0.00879797073539293
# CMI: 0.004061357677614091
# CMI: 0.001418741524791739
# CMI: 0.011423480848789913
# CMI: 0.001919387318227772
# CMI: 0.005264739302962229
# CMI: 0.004176771964593373
# CMI: 0.005257522246776808
# CMI: 0.009096792637944273
# CMI: 0.00017543628559471558
# CMI: 0.0016647297641070868
# CMI: 0.015411066173694477
# CMI: 0.007681899011376725
# CMI: 0.0024151653683771868
# CMI: 0.0003105862578302032
# CMI: 0.0023540502578490996
# CMI: 0.009170282511572536
# CMI: 0.0014573268448239696
# CMI: 0.009826242605842944
# Highest CMI score: 0.024842462259006076
# Adding original feature: 31
# CMI: 0.0016714923836287643
# CMI: 0.010219515972268556
# CMI: 0.0008328012281224595
# CMI: 0.012580174334512834
# CMI: 0.00202617832718352
# CMI: 0.02613586897895087
# CMI: 0.017523196711641043
# CMI: 0.003087185908645179
# CMI: 0.007207071911809998
# CMI: 0.005921263047837938
# CMI: 0.0005832867987067003
# CMI: 0.004559777204986626
# CMI: 0.005160410358995199
# CMI: 0.0060067406337245555
# CMI: 0.00458938508831358
# CMI: 0.015454551856190185
# CMI: 0.015185432598426085
# Highest CMI score: 0.02613586897895087
# Adding original feature: 100
# CMI: 0.0066772363442529625
# CMI: 0.004767528749244243
# CMI: 0.002368723356510588
# CMI: 7.040545927708419e-05
# CMI: 0.0015037846653143394
# CMI: 0.0012107702338231274
# Highest CMI score: 0.0066772363442529625
# Adding original feature: 66
# Highest CMI score: -0.003980576741376002
#
# [68, 113, 94, 31, 100, 66]
#
# Full aggregate regression train score: 0.4797963011685116, test score: 0.25922974424038114
# Aggregate regression train score with FS: 0.2150458052217551, test score: 0.24190284142800322

# %% [markdown]
# ### not considering last years

# %%
### emiliani2

# %%
path='/Users/paolo/Documents/OneDrive - Politecnico di Milano/droughts/features/csv_mean/features_with_aggregations.csv'

df_emil = pd.read_csv(path)
df_emil = df_emil.loc[:,['date','cyclostationary_mean_Emiliani2_rr',
                        'cyclostationary_mean_Emiliani2_rr_1w',
                        'cyclostationary_mean_Emiliani2_rr_4w',
                        'cyclostationary_mean_Emiliani2_rr_8w',
                        'cyclostationary_mean_Emiliani2_rr_12w',
                        'cyclostationary_mean_Emiliani2_rr_16w',
                        'cyclostationary_mean_Emiliani2_rr_24w',
                        'cyclostationary_mean_Emiliani2_tg',
                        'cyclostationary_mean_Emiliani2_tg_1w',
                        'cyclostationary_mean_Emiliani2_tg_4w',
                        'cyclostationary_mean_Emiliani2_tg_8w',
                        'cyclostationary_mean_Emiliani2_tg_12w',
                        'cyclostationary_mean_Emiliani2_tg_16w',
                        'cyclostationary_mean_Emiliani2_tg_24w']]

full_df_emil = df_emil.set_index('date').join(target_df.set_index('date').loc[:,'mean'],on='date')
full_df_emil = full_df_emil[:-114]
full_df_emil = full_df_emil.sample(frac=1,random_state=42).reset_index().iloc[:,1:]
full_df_emil = (full_df_emil-full_df_emil[0:587].mean())/full_df_emil[0:522].std()
full_df_emil = full_df_emil.rename(columns={'mean':'mean_std'})
full_df_emil
# Out:
#      cyclostationary_mean_Emiliani2_rr  cyclostationary_mean_Emiliani2_rr_1w  \
# 0                             3.137763                              1.253949
# 1                            -0.011466                              0.017953
# 2                            -0.329903                             -0.545009
# 3                            -0.459953                             -0.545016
# 4                            -0.254981                             -0.447667
# ..                                 ...                                   ...
# 862                          -0.920180                             -1.299560
# 863                          -1.879523                             -1.049745
# 864                          -0.127234                             -0.652994
# 865                          -0.189983                             -0.328794
# 866                          -0.951233                             -1.181660
#
#      cyclostationary_mean_Emiliani2_rr_4w  \
# 0                                2.181901
# 1                                0.072129
# 2                               -0.778419
# 3                                0.059672
# 4                               -0.645477
# ..                                    ...
# 862                             -0.701741
# 863                             -2.620077
# 864                             -0.529415
# 865                              1.159546
# 866                             -1.528845
#
#      cyclostationary_mean_Emiliani2_rr_8w  \
# 0                                0.468638
# 1                                0.448192
# 2                               -0.187246
# 3                                0.101762
# 4                               -0.313133
# ..                                    ...
# 862                             -1.294808
# 863                             -2.225628
# 864                             -0.710224
# 865                              0.539387
# 866                             -1.726350
#
#      cyclostationary_mean_Emiliani2_rr_12w  \
# 0                                -0.198191
# 1                                 0.858997
# 2                                -0.341337
# 3                                -0.269854
# 4                                -0.770727
# ..                                     ...
# 862                              -1.530390
# 863                              -1.229755
# 864                              -0.479075
# 865                               0.771848
# 866                              -0.918537
#
#      cyclostationary_mean_Emiliani2_rr_16w  \
# 0                                -0.381265
# 1                                 0.765849
# 2                                -0.573176
# 3                                -0.678169
# 4                                -0.170846
# ..                                     ...
# 862                              -0.919833
# 863                              -0.511595
# 864                              -0.238358
# 865                               0.727042
# 866                               0.240039
#
#      cyclostationary_mean_Emiliani2_rr_24w  cyclostationary_mean_Emiliani2_tg  \
# 0                                 0.776173                          -1.731953
# 1                                 0.479436                           0.154758
# 2                                -1.138025                           1.398985
# 3                                -0.611521                           1.014296
# 4                                 0.202178                           1.329270
# ..                                     ...                                ...
# 862                              -0.437819                           0.562016
# 863                              -0.806448                           0.686745
# 864                               0.814797                           0.713365
# 865                               0.925804                           1.121717
# 866                              -0.214449                           0.299039
#
#      cyclostationary_mean_Emiliani2_tg_1w  \
# 0                               -0.912991
# 1                                0.454989
# 2                                0.596533
# 3                                1.077430
# 4                                1.010015
# ..                                    ...
# 862                              0.407474
# 863                              1.074422
# 864                              1.742598
# 865                              1.156031
# 866                             -0.520615
#
#      cyclostationary_mean_Emiliani2_tg_4w  \
# 0                                0.037496
# 1                               -0.325855
# 2                                0.269121
# 3                                1.424495
# 4                                0.753830
# ..                                    ...
# 862                             -0.689512
# 863                              0.568207
# 864                              2.278680
# 865                              0.088506
# 866                             -0.211315
#
#      cyclostationary_mean_Emiliani2_tg_8w  \
# 0                                0.020651
# 1                               -0.907882
# 2                               -0.464928
# 3                                0.539859
# 4                                0.064039
# ..                                    ...
# 862                             -0.698752
# 863                              0.692155
# 864                              2.342668
# 865                             -0.090556
# 866                             -0.823204
#
#      cyclostationary_mean_Emiliani2_tg_12w  \
# 0                                 0.107443
# 1                                -0.964694
# 2                                -0.516485
# 3                                 0.312970
# 4                                 0.477932
# ..                                     ...
# 862                              -1.050392
# 863                               0.300246
# 864                               2.296453
# 865                               0.013436
# 866                              -0.355516
#
#      cyclostationary_mean_Emiliani2_tg_16w  \
# 0                                 0.042016
# 1                                -0.776038
# 2                                 0.045693
# 3                                 0.038473
# 4                                 0.385753
# ..                                     ...
# 862                              -0.649898
# 863                              -0.084478
# 864                               2.575864
# 865                              -0.323670
# 866                               0.241209
#
#      cyclostationary_mean_Emiliani2_tg_24w  mean_std
# 0                                -0.464475 -0.659768
# 1                                -0.580594 -0.291700
# 2                                -0.754607 -0.424929
# 3                                 0.261657 -0.764559
# 4                                 0.304312 -0.775374
# ..                                     ...       ...
# 862                              -0.098451 -1.542125
# 863                              -0.019234 -0.599071
# 864                               1.337449  0.334537
# 865                              -0.602247  0.612434
# 866                              -0.156447  0.042128
#
# [867 rows x 15 columns]

# %%
### wrapper FS, linear regression

selected_colnames = FS_with_linearWrapper(full_df_emil.iloc[0:696,:-1], full_df_emil.iloc[0:522], full_df_emil.iloc[522:696], max_feat=12 , val_len=174)
compare_methods(full_df_emil.iloc[0:696,:-1], full_df_emil.iloc[696:,:-1], full_df_emil.iloc[0:696], full_df_emil.iloc[696:], selected_colnames)
# Out:
# actual training score: 0.19207909117865352
# actual validation score: 0.20525185197614915, number of remaining columns: 12
#
# actual training score: 0.20522479304882457
# actual validation score: 0.2228733815190136, number of remaining columns: 11
#
# actual training score: 0.21511622817393383
# actual validation score: 0.23449632537562248, number of remaining columns: 10
#
# actual training score: 0.21525595918709983
# actual validation score: 0.23665104026055783, number of remaining columns: 9
#
# actual training score: 0.2155552073519167
# actual validation score: 0.23738719114008966, number of remaining columns: 8
#
# actual training score: 0.21580491912129685
# actual validation score: 0.23782823219082838, number of remaining columns: 7
#
# actual training score: 0.2169371299044841
# actual validation score: 0.23554419959816897, number of remaining columns: 6
#
# actual training score: 0.2256468809397436
# actual validation score: 0.23217121166979848, number of remaining columns: 5
#
# actual training score: 0.23346728448853826
# actual validation score: 0.22436343863604113, number of remaining columns: 4
#
# actual training score: 0.23837391079415093
# actual validation score: 0.21672160449742695, number of remaining columns: 3
#
# actual training score: 0.2401530959163639
# actual validation score: 0.21478152374264226, number of remaining columns: 2
#
# actual training score: 0.24061166741297346
# actual validation score: 0.21070235696172213, number of remaining columns: 1
#
#
#
# selected columns: ['cyclostationary_mean_Emiliani2_rr_4w', 'cyclostationary_mean_Emiliani2_tg_1w', 'cyclostationary_mean_Emiliani2_tg_24w', 'cyclostationary_mean_Emiliani2_rr_12w', 'cyclostationary_mean_Emiliani2_rr_16w', 'cyclostationary_mean_Emiliani2_rr_24w', 'cyclostationary_mean_Emiliani2_rr_8w'],
#
# validation score: 0.23782823219082838,
#
# number of selected features: 7
# Full aggregate regression train score: 0.23835171638403174, test score: 0.20797702704189458
# Aggregate regression train score with FS: 0.22313216964401472, test score: 0.15610008834095157

# %%
### CMI FS, linear regression

res = {
    "delta" : [], # list with all deltas
    "numSelected" : [], #
    "selectedFeatures" : [] 
}

res['selectedFeatures'] = forwardFeatureSelection(10,np.array(full_df_emil.iloc[0:696,:-1]),np.array(full_df_emil.iloc[0:696,-1]),res,10,1)
selectedFeatures='selectedFeatures'
print(f'\n{res[selectedFeatures]}\n')
selected_colnames = full_df_emil.iloc[0:696,:-1].columns[res['selectedFeatures']]
compare_methods(full_df_emil.iloc[0:696,:-1], full_df_emil.iloc[696:,:-1], full_df_emil.iloc[0:696], full_df_emil.iloc[696:], selected_colnames)
# Out:
# ----- MI Scores -----
# [(8, 0.10785149396760195), (7, 0.0925598801150079), (4, 0.08573739171513929), (3, 0.06919918548391668), (1, 0.06846795273706198), (2, 0.06801108095247393), (0, 0.062210882090445334), (5, 0.0490032047453643), (9, 0.045858418932004714), (6, 0.02590810773838242), (10, 0.025728206674913337), (11, 0.017848888073754034), (12, 0.010638385809115239), (13, 0.006162598157561256)]
# Best MI score: 0.10785149396760195
# Adding first best original feature: 8
# CMI: 0.028897808187487314
# CMI: 0.0459666787351949
# CMI: 0.05127150084619923
# CMI: 0.07830366322577818
# CMI: 0.07029450796278795
# CMI: 0.05542789877949962
# CMI: 0.03009536146948509
# CMI: 0.01669249553935731
# CMI: 0.020169126521406386
# CMI: 0.023260041967649983
# CMI: 0.008706104840388099
# Highest CMI score: 0.07830366322577818
# Adding original feature: 3
# CMI: 0.005326730005477093
# CMI: 0.007298483191220562
# CMI: 0.02557754808247603
# CMI: 0.011856590857385413
# CMI: 0.017954700737115192
# CMI: 0.008096350040648154
# CMI: 0.026943284884130836
# CMI: 0.04012000043981376
# CMI: 0.039052741187507484
# CMI: 0.020447949232884982
# CMI: 0.04276143232328411
# Highest CMI score: 0.04276143232328411
# Adding original feature: 13
# CMI: 0.003521006845430663
# CMI: 0.0009378332773636588
# Highest CMI score: 0.003521006845430663
# Adding original feature: 5
# CMI: 0.0036234720719464375
# CMI: 0.009421883386996566
# CMI: 0.0020816109536784255
# CMI: 0.0009563498336513376
# Highest CMI score: 0.009421883386996566
# Adding original feature: 6
# CMI: 0.002049345693293375
# Highest CMI score: 0.002049345693293375
# Adding original feature: 12
# Highest CMI score: -0.002570559675581313
#
# [8, 3, 13, 5, 6, 12]
#
# Full aggregate regression train score: 0.23835171638403174, test score: 0.20797702704189458
# Aggregate regression train score with FS: 0.2163871623440362, test score: 0.14896268525886913

# %%
### all

# %%
path='/Users/paolo/Documents/OneDrive - Politecnico di Milano/droughts/features/csv_mean/features_with_aggregations.csv'

df = pd.read_csv(path)

full_df = df.set_index('date').join(target_df.set_index('date').loc[:,'mean'],on='date')
full_df = full_df[:-114]
full_df = full_df.sample(frac=1,random_state=42).reset_index().iloc[:,1:]
full_df = (full_df-full_df[0:587].mean())/full_df[0:522].std()
full_df = full_df.rename(columns={'mean':'mean_std'})
full_df
# Out:
#      cyclostationary_mean_Adda_tg  cyclostationary_mean_Dora_tg  \
# 0                       -1.758187                     -2.033375
# 1                       -0.596105                     -0.665636
# 2                        1.170615                      1.514403
# 3                        0.513674                      0.709105
# 4                        1.346417                      1.397291
# ..                            ...                           ...
# 862                      0.350608                      0.348667
# 863                      1.096878                      1.559192
# 864                     -0.164125                     -0.144956
# 865                      1.641897                      1.629234
# 866                      0.618987                      0.894211
#
#      cyclostationary_mean_Emiliani1_tg  cyclostationary_mean_Piemonte_Sud_tg  \
# 0                            -1.221340                             -2.029975
# 1                             0.480257                             -0.560292
# 2                             1.364940                              1.469126
# 3                             1.066441                              1.440118
# 4                             1.089196                              1.336848
# ..                                 ...                                   ...
# 862                           0.766686                              0.442571
# 863                           0.409483                              1.409023
# 864                           0.136503                              0.709879
# 865                           0.986825                              1.347709
# 866                           0.251651                              0.349553
#
#      cyclostationary_mean_Piemonte_Nord_tg  \
# 0                                -1.869988
# 1                                -0.762011
# 2                                 1.460958
# 3                                 1.212746
# 4                                 1.430618
# ..                                     ...
# 862                               0.332239
# 863                               1.440078
# 864                               0.446372
# 865                               1.492818
# 866                               0.545715
#
#      cyclostationary_mean_Oglio_Iseo_tg  cyclostationary_mean_Ticino_tg  \
# 0                             -1.600931                       -1.646392
# 1                             -0.237416                       -0.653932
# 2                              1.451657                        1.413544
# 3                              0.474372                        0.741635
# 4                              1.454830                        1.496827
# ..                                  ...                             ...
# 862                            0.471640                        0.333891
# 863                            1.010069                        1.333960
# 864                            0.042827                       -0.099763
# 865                            1.694247                        1.791308
# 866                            0.460034                        0.720066
#
#      cyclostationary_mean_Garda_Mincio_tg  \
# 0                               -1.355072
# 1                               -0.039245
# 2                                1.541356
# 3                                0.707087
# 4                                1.398917
# ..                                    ...
# 862                              0.403558
# 863                              0.812876
# 864                              0.090968
# 865                              1.257996
# 866                              0.303017
#
#      cyclostationary_mean_Lambro_Olona_tg  cyclostationary_mean_Emiliani2_tg  \
# 0                               -1.816625                          -1.731953
# 1                               -0.426897                           0.154758
# 2                                1.312803                           1.398985
# 3                                1.463315                           1.014296
# 4                                1.478756                           1.329270
# ..                                    ...                                ...
# 862                              0.305765                           0.562016
# 863                              1.116827                           0.686745
# 864                              0.578833                           0.713365
# 865                              1.234425                           1.121717
# 866                              0.213279                           0.299039
#
#      ...  cyclostationary_mean_Lambro_Olona_rr_12w  \
# 0    ...                                  0.042774
# 1    ...                                  0.537901
# 2    ...                                  0.765946
# 3    ...                                 -0.469616
# 4    ...                                 -0.413923
# ..   ...                                       ...
# 862  ...                                 -1.673113
# 863  ...                                 -0.819908
# 864  ...                                  1.420184
# 865  ...                                  0.265646
# 866  ...                                 -1.105985
#
#      cyclostationary_mean_Lambro_Olona_rr_16w  \
# 0                                   -0.127681
# 1                                    0.627999
# 2                                    0.899758
# 3                                   -0.903569
# 4                                    0.456834
# ..                                        ...
# 862                                 -1.494331
# 863                                 -0.508847
# 864                                  1.050460
# 865                                  0.449629
# 866                                  0.744528
#
#      cyclostationary_mean_Lambro_Olona_rr_24w  \
# 0                                    1.183497
# 1                                    0.394173
# 2                                    0.503096
# 3                                   -0.672614
# 4                                    0.736452
# ..                                        ...
# 862                                 -0.253450
# 863                                 -1.023851
# 864                                  0.910831
# 865                                  0.529982
# 866                                  0.170708
#
#      cyclostationary_mean_Emiliani2_rr_1w  \
# 0                                1.253949
# 1                                0.017953
# 2                               -0.545009
# 3                               -0.545016
# 4                               -0.447667
# ..                                    ...
# 862                             -1.299560
# 863                             -1.049745
# 864                             -0.652994
# 865                             -0.328794
# 866                             -1.181660
#
#      cyclostationary_mean_Emiliani2_rr_4w  \
# 0                                2.181901
# 1                                0.072129
# 2                               -0.778419
# 3                                0.059672
# 4                               -0.645477
# ..                                    ...
# 862                             -0.701741
# 863                             -2.620077
# 864                             -0.529415
# 865                              1.159546
# 866                             -1.528845
#
#      cyclostationary_mean_Emiliani2_rr_8w  \
# 0                                0.468638
# 1                                0.448192
# 2                               -0.187246
# 3                                0.101762
# 4                               -0.313133
# ..                                    ...
# 862                             -1.294808
# 863                             -2.225628
# 864                             -0.710224
# 865                              0.539387
# 866                             -1.726350
#
#      cyclostationary_mean_Emiliani2_rr_12w  \
# 0                                -0.198191
# 1                                 0.858997
# 2                                -0.341337
# 3                                -0.269854
# 4                                -0.770727
# ..                                     ...
# 862                              -1.530390
# 863                              -1.229755
# 864                              -0.479075
# 865                               0.771848
# 866                              -0.918537
#
#      cyclostationary_mean_Emiliani2_rr_16w  \
# 0                                -0.381265
# 1                                 0.765849
# 2                                -0.573176
# 3                                -0.678169
# 4                                -0.170846
# ..                                     ...
# 862                              -0.919833
# 863                              -0.511595
# 864                              -0.238358
# 865                               0.727042
# 866                               0.240039
#
#      cyclostationary_mean_Emiliani2_rr_24w  mean_std
# 0                                 0.776173 -0.659768
# 1                                 0.479436 -0.291700
# 2                                -1.138025 -0.424929
# 3                                -0.611521 -0.764559
# 4                                 0.202178 -0.775374
# ..                                     ...       ...
# 862                              -0.437819 -1.542125
# 863                              -0.806448 -0.599071
# 864                               0.814797  0.334537
# 865                               0.925804  0.612434
# 866                              -0.214449  0.042128
#
# [867 rows x 141 columns]

# %%
### wrapper FS, linear regression

selected_colnames = FS_with_linearWrapper(full_df.iloc[0:696,:-1], full_df.iloc[0:522], full_df.iloc[522:696], max_feat=12 , val_len=174)
compare_methods(full_df.iloc[0:696,:-1], full_df.iloc[696:,:-1], full_df.iloc[0:696], full_df.iloc[696:], selected_colnames)
# Out:
# actual training score: 0.20378426048248366
# actual validation score: 0.2427999631369473, number of remaining columns: 138
#
# actual training score: 0.2071742141923142
# actual validation score: 0.25420934405757545, number of remaining columns: 137
#
# actual training score: 0.22806836001534014
# actual validation score: 0.26825654281206346, number of remaining columns: 136
#
# actual training score: 0.2412188981512392
# actual validation score: 0.2830869009771929, number of remaining columns: 135
#
# actual training score: 0.24461617928422774
# actual validation score: 0.2986721151198445, number of remaining columns: 134
#
# actual training score: 0.24710993381251167
# actual validation score: 0.3151158528836042, number of remaining columns: 133
#
# actual training score: 0.2513158109754534
# actual validation score: 0.3252643237897356, number of remaining columns: 132
#
# actual training score: 0.2551025844651862
# actual validation score: 0.3285914256350678, number of remaining columns: 131
#
# actual training score: 0.2575720298978006
# actual validation score: 0.33208404068448805, number of remaining columns: 130
#
# actual training score: 0.2604075548198791
# actual validation score: 0.3363339254984734, number of remaining columns: 129
#
# actual training score: 0.26224952746057417
# actual validation score: 0.3386534446298972, number of remaining columns: 128
#
# actual training score: 0.2712633819281467
# actual validation score: 0.34137234301558905, number of remaining columns: 127
#
#
#
# selected columns: ['cyclostationary_mean_Emiliani1_rr_4w', 'cyclostationary_mean_Ticino_tg', 'cyclostationary_mean_Emiliani2_tg_24w', 'cyclostationary_mean_Emiliani1_tg_1w', 'cyclostationary_mean_Lambro_Olona_rr_12w', 'cyclostationary_mean_Oglio_Iseo_rr_16w', 'cyclostationary_mean_Piemonte_Nord_tg', 'cyclostationary_mean_Piemonte_Sud_rr_12w', 'cyclostationary_mean_Dora_rr_24w', 'cyclostationary_mean_Dora_rr_12w', 'cyclostationary_mean_Lambro_Olona_rr_24w', 'cyclostationary_mean_Emiliani1_tg_24w', 'cyclostationary_mean_Lambro_Olona_tg_1w'],
#
# validation score: 0.34137234301558905,
#
# number of selected features: 13
# Full aggregate regression train score: 0.5147474556658631, test score: 0.14645440245848917
# Aggregate regression train score with FS: 0.28962116116605574, test score: 0.21352711740585517

# %%
### CMI FS, linear regression

res = {
    "delta" : [], # list with all deltas
    "numSelected" : [], #
    "selectedFeatures" : [] 
}

res['selectedFeatures'] = forwardFeatureSelection(10,np.array(full_df.iloc[0:696,:-1]),np.array(full_df.iloc[0:696,-1]),res,10,1)
selectedFeatures='selectedFeatures'
print(f'\n{res[selectedFeatures]}\n')
selected_colnames = full_df.iloc[0:696,:-1].columns[res['selectedFeatures']]
compare_methods(full_df.iloc[0:696,:-1], full_df.iloc[696:,:-1], full_df.iloc[0:696], full_df.iloc[696:], selected_colnames)
# Out:
# ----- MI Scores -----
# [(38, 0.12525279788700655), (20, 0.1242244889241374), (68, 0.11756652913766734), (93, 0.11418231052810235), (44, 0.10940977531524726), (56, 0.1089491031168935), (74, 0.10785149396760195), (6, 0.10396690353784173), (8, 0.10212088871487965), (92, 0.10162089330494874), (26, 0.09717563121719888), (0, 0.09529656706491889), (3, 0.09499684951475833), (9, 0.0925598801150079), (122, 0.0924392394698762), (62, 0.08989574790286198), (5, 0.08886401753593759), (50, 0.08859160318190125), (1, 0.08794628031977536), (137, 0.08573739171513929), (102, 0.08