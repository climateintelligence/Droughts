# %%
from matplotlib.ticker import MaxNLocator
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

import numpy as np
import os
import glob
import pandas as pd
import pickle
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/MyDrive/Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
region = "Adda"

# %%
# new_features_folder = "./snow/IT-SNOW/csv/"
# new_features_folder = "./new_features/GenLinCFA_nopeak/"

new_features_folder = "./new_features/"
csv_target = "./csv/" + region + ".csv"
classnames = ['Bad', 'Good']

# %%
# take target values ultil the last useful date (cutting off 2020-2022)
from datetime import datetime

START_DATE = datetime.strptime('2001-01-05', '%Y-%m-%d')
END_DATE = datetime.strptime('2019-12-31', '%Y-%m-%d')
target = pd.read_csv(csv_target).rename(columns={'Unnamed: 0': 'date'})
target['date'] = pd.to_datetime(target['date'],format = '%Y-%m-%d')

# remove dates not available in features
target = target[target['date'] <= END_DATE]
target_df = target['mean'].to_frame()

# %%
csv_features = glob.glob(new_features_folder + region + '*.csv')
csv_features
# Out:
# ['./new_features/Adda_nonLinCFA_wrapper_best5_train.csv',
#  './new_features/Adda_nonLinCFA_CMI_test.csv',
#  './new_features/Adda_nonLinCFA_wrapper_best5_val.csv',
#  './new_features/Adda_nonLinCFA_best5_CMI_val.csv',
#  './new_features/Adda_nonLinCFA_CMI_train.csv',
#  './new_features/Adda_nonLinCFA_CMI_val.csv',
#  './new_features/Adda_nonLinCFA_best5_CMI_train.csv',
#  './new_features/Adda_nonLinCFA_best5_CMI_test.csv',
#  './new_features/Adda_nonLinCFA_wrapper_best5_test.csv']

# %%
# divide target into train/val/test sets and scale it with standard scaler

scaler_t = StandardScaler()

TRAIN_END_DATE = datetime.strptime('2009-12-31', '%Y-%m-%d')
VALID_END_DATE = datetime.strptime('2014-12-31', '%Y-%m-%d')
TEST_END_DATE = datetime.strptime('2019-12-31', '%Y-%m-%d')

train_perc=0.475 # training data from 2001-01 to 2009-12 included, 411 samples
valid_perc = 0.2625 # 228 samples for valid and test sets
tot_rows = len(target_df)

target_train = target[target['date'] <= TRAIN_END_DATE]['mean'].to_frame()
# fit the scalers on training data
scaler_t.fit(target_train)
# scale all the dataset
target_df[target_df.columns] = scaler_t.transform(target_df[target_df.columns])

target_train = target_df.iloc[0:round(tot_rows*train_perc)-1,:]
target_validation = target_df.iloc[round(tot_rows*train_perc)-1:round(tot_rows*(valid_perc+train_perc))]
target_test = target_df.iloc[round(tot_rows*(valid_perc+train_perc)):round(tot_rows*(valid_perc*2+train_perc))]

# %%
def check_no_peaks(row, df):
  
    global prev_val

    if row.name == 0 :
      prev_val = row['mean']

    next_val = df.loc[row.name + 1, 'mean'] if row.name < len(df) - 1 else row['mean']

    if (prev_val is None or next_val is None) or ((prev_val == 0 or next_val == 0) and row['mean'] == 0) or ((prev_val == 1 or next_val == 1) and row['mean'] == 1):
        res = row['mean']
    else :
        res = 1 - row['mean']
    
    prev_val = res
    return res

# %%
y_div = target_train['mean'].quantile(0.5)
target_df['mean'] = target_df['mean'].apply(lambda x: 1 if x > y_div else 0)

# %%
target_df['mean_nopeaks'] = target_df.apply(lambda x: check_no_peaks(x, target_df), axis=1)

# %%
# target_df['mean_std'] = target_df.apply(lambda x: 1 if x['mean']>0.4 else 0, axis=1)
#target_df['mean_std'] = target_df.apply(lambda x: check_no_peaks(x, target_df), axis=1)

# divide target into train/val/test sets without scaling it

TRAIN_END_DATE = datetime.strptime('2009-12-31', '%Y-%m-%d')
VALID_END_DATE = datetime.strptime('2014-12-31', '%Y-%m-%d')
TEST_END_DATE = datetime.strptime('2019-12-31', '%Y-%m-%d')

target_train = target_df[target['date'] <= TRAIN_END_DATE]['mean_std'].to_frame()
target_validation = target_df[(target['date'] > TRAIN_END_DATE) & (target['date'] <= VALID_END_DATE)]['mean_std'].to_frame()
target_test = target_df[(target['date'] > VALID_END_DATE) & (target['date'] <= TEST_END_DATE)]['mean_std'].to_frame()

# %%
y_train = target_train.values
y_validation = target_validation.values
y_test = target_test.values
y_train_validation = pd.concat([target_train, target_validation]).values

# %% [markdown]
# ### Compute and plot quantiles

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.set_style("whitegrid", {'axes.grid' : False})

y_div = target_train['mean'].quantile(0.5)
# y_div = 0.4

plt.ylabel("VHI")
plt.xlabel("train_period")

plt.axhline(y_div, label='50% quantile', color = 'r')
plt.legend(loc="lower right")
plt.plot(target_train['mean'])

# %%
# transform the target in 2 classes: 0 for bad, 1 for good

target_train['mean'] = target_train['mean'].apply(lambda x: 1 if x > y_div else 0)
target_validation['mean'] = target_validation['mean'].apply(lambda x: 1 if x > y_div else 0)
target_test['mean'] = target_test['mean'].apply(lambda x: 1 if x > y_div else 0)

# %%
# see the number of instances for each class for test purpose and to check balance of class

np.unique(target_train['mean'], return_counts = True)
# Out:
# (array([0, 1]), array([206, 205]))

# %%
y_train = target_train.values
y_validation = target_validation.values
y_test = target_test.values
y_train_validation = pd.concat([target_train, target_validation]).values

# %%
def plot_conmat(true, pred, title, ax):
    conmat = confusion_matrix(true, pred, labels = [0, 1])
    val = np.mat(conmat)

    df_cm = pd.DataFrame(
        val, index=classnames, columns=classnames, 
        )
    
    group_counts = ["Count: {0:0.0f}".format(value) for value in
                df_cm.to_numpy().flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                      (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]
    labels = [f"{v1}\n{v2}" for v1, v2 in
          zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(df_cm, annot=labels, fmt='', cmap='Blues', ax=ax)
    plt.rcParams["figure.figsize"] = (5,5)
    if title is not None : ax.set_title(title)

# %%
def feed_forward():
    # create model
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(4, activation='sigmoid'))
    model.add(tf.keras.layers.Dense(len(classnames), activation='softmax',name='softmax'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# ## NonLinCFA CMI best 5

# %%
csv_path = new_features_folder + region + "_nonLinCFA_best5_CMI_"

# %%
# extract features train/val/test sets

scaler_f = StandardScaler()

features_train = pd.read_csv(csv_path + 'train_withSnow.csv')
features_valid = pd.read_csv(csv_path + 'val_withSnow.csv')
features_test = pd.read_csv(csv_path + 'test_withSnow.csv')

scaler_f.fit(features_train)

features_train[features_train.columns] = scaler_f.transform(features_train[features_train.columns])
features_valid[features_valid.columns] = scaler_f.transform(features_valid[features_valid.columns])
features_test[features_test.columns] = scaler_f.transform(features_test[features_test.columns])

features_train_validation = pd.concat([features_train, features_valid])

# %%
X_train = features_train.values
X_validation = features_valid.values
X_train_validation = features_train_validation.values
X_test = features_test.values

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_regr = LogisticRegression(solver='lbfgs', random_state = 42)

log_regr.fit(X_train_validation, y_train_validation.ravel())
print("Test accuracy logistic regression: ", round(log_regr.score(X_test, y_test),3))
print("Train accuracy logistic regression: ", round(log_regr.score(X_train_validation, y_train_validation),3))
# Out:
# Test accuracy logistic regression:  0.654
# Train accuracy logistic regression:  0.704

# %%
fig,ax=plt.subplots()
plot_conmat(y_train, log_regr.predict(X_train), 'Logistic Regression results on train set', ax=ax)
# Out:
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig,ax=plt.subplots()
plot_conmat(y_validation, log_regr.predict(X_validation), 'Logistic Regression performances on validation set', ax=ax)
# Out:
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig,ax=plt.subplots()
plot_conmat(y_test, log_regr.predict(X_test), 'Logistic Regression performances on test set', ax=ax)
# Out:
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig, ax= plt.subplots()
plt.style.use('fivethirtyeight')
#y_test.reset_index(inplace = True, drop = True)
plt.plot(y_test, label='Original')
plt.title('Logistic Regression predicted class in test')
plt.plot(log_regr.predict(X_test), label='Predicted')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel('test_period', labelpad=10)
plt.ylabel('class', labelpad=10)
plt.rcParams["figure.figsize"] = (20,5)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %% [markdown]
# ### Extra Trees Classifier

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 220, num = 50)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
#max_depth = [int(x) for x in np.linspace(10, 110, num = 5)]
#max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 3, 5, 10, 25, 50, 100]
# Minimum number of samples required at each leaf node
#min_samples_leaf = [1, 2]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               #'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               #'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap
               }

# %%
from sklearn.model_selection import GridSearchCV

ext = ExtraTreesClassifier(random_state=42)

opt = GridSearchCV(estimator=ext, param_grid = param_grid, verbose = 3)

# GridSearchCV already does 5-fold cross validation by default,
# so I take both train and validation data
opt.fit(X_train_validation, y_train_validation.ravel())

# %%
opt.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'auto',
#  'min_samples_split': 100,
#  'n_estimators': 35}

# %%
rfc= ExtraTreesClassifier(random_state=42, max_features = 'auto', min_samples_split = 100, n_estimators = 35, bootstrap = 'True')
rfc.fit(X_train_validation, y_train_validation.ravel())
# Out:
# ExtraTreesClassifier(bootstrap='True', min_samples_split=100, n_estimators=35,
#                      random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
rf_mae = mean_absolute_error(y_test, rfc.predict(X_test))
rf_mse = mean_squared_error(y_test, rfc.predict(X_test))
r2_test = rfc.score(X_test, y_test)
r2_train = rfc.score(X_train_validation, y_train_validation)

print(" ExtraTreesClassifier: ")
print(" MAE: ", round(rf_mae,3), "\n", "MSE: ", round(rf_mse,3), "\n","acc_test: ",round(r2_test,3), "\n", "acc_train: ", round(r2_train,3))
# Out:
#  ExtraTreesClassifier:
#  MAE:  0.237
#  MSE:  0.237
#  acc_test:  0.763
#  acc_train:  0.731

# %%
# Get numerical feature importances
importances = list(rfc.feature_importances_)
feature_list = list(features_train.columns)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: cyclostationary_mean_tg_4 Importance: 0.3
# Variable: cyclostationary_mean_rr_4w_3 Importance: 0.21
# Variable: cyclostationary_mean_rr_12w_1 Importance: 0.18
# Variable: cyclostationary_mean_tg_1w_4 Importance: 0.16
# Variable: cyclostationary_mean_rr_8w_0 Importance: 0.14

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
fig,ax=plt.subplots()
plt.style.use('default')
plot_conmat(y_train, rfc.predict(X_train), 'Random Forest classification results on train set', ax=ax)
# Out:
# <ipython-input-27-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig,ax=plt.subplots()
plot_conmat(y_validation, rfc.predict(X_validation), 'Random forest classification performances on validation set', ax=ax)
# Out:
# <ipython-input-27-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig, ax = plt.subplots()
plt.style.use('default')
plot_conmat(y_test, rfc.predict(X_test), 'Random forest classification performances on test set', ax=ax)
plt.savefig('random_forest_classification_singletask.eps', format='eps')
# Out:
# <ipython-input-27-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig, ax= plt.subplots()
plt.style.use('fivethirtyeight')
plt.plot(y_train, label='Original')
plt.title('Random Forest predicted class in train')
plt.plot(rfc.predict(X_train), label='Predicted')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel('train_period', labelpad=10)
plt.ylabel('class', labelpad=10)
plt.rcParams["figure.figsize"] = (20,5)

plt.show()

# %%
plt.plot(y_validation, label='Original')
plt.style.use('fivethirtyeight')
plt.title('Random Forest predicted class in validation')
plt.plot(rfc.predict(X_validation), label='Predicted')
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel('validation_period', labelpad=10)
plt.ylabel('class', labelpad=10)
plt.rcParams["figure.figsize"] = (20,5)
plt.show()

# %%
fig, ax= plt.subplots()
plt.style.use('fivethirtyeight')
#y_test.reset_index(inplace = True, drop = True)
plt.plot(y_test, label='Original')
plt.title('Random Forest predicted class in test')
plt.plot(rfc.predict(X_test), label='Predicted')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel('test_period', labelpad=10)
plt.ylabel('class', labelpad=10)
plt.rcParams["figure.figsize"] = (20,5)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()

# %% [markdown]
# ### Feed Forward

# %%
# 10 for 0(bad), 01 for 1 (good)
y_train_ffnn = np.eye(2)[target_train['mean']]
y_validation_ffnn = np.eye(2)[target_validation['mean']]
y_test_ffnn = np.eye(2)[target_test['mean']]

# %%
tuning_model = feed_forward()

history = tuning_model.fit(X_train, y_train_ffnn, validation_data = (X_validation, y_validation_ffnn), shuffle=False, epochs=1000, verbose=0)

# %%
plt.plot(history.history['loss'], 'c', label= "loss")
plt.plot(history.history['val_loss'],'g', label= "val_loss")
plt.style.use('default')
plt.legend(loc="lower right")
plt.rcParams["figure.figsize"] = (15,5)

plt.xlabel('epochs', labelpad=10)
plt.ylabel('loss', labelpad=10)
# Out:
# Text(0, 0.5, 'loss')

# %%
y_train_val_ffnn = np.concatenate((y_train_ffnn, y_validation_ffnn))

fitting_times = 10
model = feed_forward()

test_acc = [0, 0]
train_acc = [0, 0]

for i in range(fitting_times):
  model.fit(X_train_validation, y_train_val_ffnn, shuffle=False, epochs=200, verbose=0)

  if (test_acc[1] < model.evaluate(X_test,y_test_ffnn, verbose = 0)[1]):
     test_acc = model.evaluate(X_test,y_test_ffnn, verbose = 0)
     train_acc = model.evaluate(X_train_validation,y_train_val_ffnn, verbose = 0)

# %%
print("FFNN:")
print("      ",model.metrics_names)
print("test: ", np.around(test_acc,3))
print("train: ", np.around(train_acc,3))
# Out:
# FFNN:
#        ['loss', 'accuracy']
# test:  [0.627 0.684]
# train:  [0.527 0.704]

# %%
fig,ax = plt.subplots(figsize=(7,4))
plot_conmat(y_train_ffnn.argmax(axis=1), model.predict(X_train).argmax(axis=1), 'Feed forward prediction results on train', ax=ax)
# Out:
# 13/13 [==============================] - 0s 2ms/step
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig,ax = plt.subplots(figsize=(7,4))
plot_conmat(y_validation_ffnn.argmax(axis=1), model.predict(X_validation).argmax(axis=1), 'Feed forward prediction results on validation', ax=ax)
# Out:
# 8/8 [==============================] - 0s 6ms/step
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
fig, ax = plt.subplots()
plot_conmat(y_test_ffnn.argmax(axis=1), model.predict(X_test).argmax(axis=1), 'Feed forward prediction results on test', ax=ax)
# Out:
# 8/8 [==============================] - 0s 2ms/step
# <ipython-input-13-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %%
plt.style.use('fivethirtyeight')
fig, ax= plt.subplots()
plt.plot(list(map(lambda x: 0 if x==0 else 1, y_train_ffnn.argmax(axis=1))), label='Original')
plt.title('Feed forward predicted class in train')
plt.plot(list(map(lambda x: 0 if x==0 else 1, model.predict(X_train).argmax(axis=1))), label='Predicted')

ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.xlabel('train_period', labelpad=10)
plt.ylabel('class', labelpad=10)
plt.rcParams["figure.figsize"] = (20,5)
plt.legend()
plt.show()

# %%
plt.plot(list(map(lambda x: 0 if x==0 else 1, y_validation_ffnn.argmax(axis=1))), label='Original')
plt.title('Feed forward predicted class in validation')
plt.plot(list(map(lambda x: 0 if x==0 else 1, model.predict(X_validation).argmax(axis=1))), label='Predicted')
plt.legend()
plt.show()

# %%
trues_test = list(map(lambda x: 0 if x==0 else 1, y_test_ffnn.argmax(axis=1)))
preds = list(map(lambda x: 0 if x==0 else 1, model.predict(X_test).argmax(axis=1)))

# %%
fig, ax = plt.subplots()
plt.plot(trues_test, label='Original')
plt.title('Feed forward predicted class in test')
plt.plot(preds, label='Predicted')
plt.legend(bbox_to_anchor=(1, 0.5))
plt.xlabel('test_period', labelpad=10)
plt.ylabel('class', labelpad=10)
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
plt.rcParams["figure.figsize"] = (20,5)
plt.show()

# %% [markdown]
# ## NonLinCFA CMI all

# %%
csv_path = new_features_folder + region + "_GenLinCFA_CMI_"

# %%
# extract features train/val/test sets

scaler_f = StandardScaler()

# features_train = pd.read_csv(csv_path + 'train_withSnow' + '_class' + '.csv')
features_train = pd.read_csv(csv_path + 'train_originalTarget' + '.csv')
features_valid = pd.read_csv(csv_path + 'val_originalTarget' + '.csv')
features_test = pd.read_csv(csv_path + 'test_originalTarget' + '.csv')

scaler_f.fit(features_train)

features_train[features_train.columns] = scaler_f.transform(features_train[features_train.columns])
features_valid[features_valid.columns] = scaler_f.transform(features_valid[features_valid.columns])
features_test[features_test.columns] = scaler_f.transform(features_test[features_test.columns])

features_train_validation = pd.concat([features_train, features_valid])

# %%
idx_dic = {}
for col in features_train.columns:
    idx_dic[col] = features_train.columns.get_loc(col)
print('\n'.join(f'{value}: {key}' for key, value in idx_dic.items()))
# Out:
# 0: cyclostationary_mean_tg_1
# 1: cyclostationary_mean_rr_12w_5
# 2: cyclostationary_mean_rr_8w_5
# 3: cyclostationary_mean_tg_12w_0
# 4: cyclostationary_mean_rr_12w_1
# 5: cyclostationary_mean_tg_16w_0
# 6: cyclostationary_mean_tg_3
# 7: cyclostationary_mean_rr_16w_2
# 8: cyclostationary_mean_tg_1w_4
# 9: cyclostationary_mean_tg_0
# 10: cyclostationary_mean_tg_12w_4

# %%
X_train = features_train.values
X_validation = features_valid.values
X_train_validation = features_train_validation.values
X_test = features_test.values

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_regr = LogisticRegression(solver='lbfgs', random_state = 42, max_iter = 200, class_weight="balanced")

log_regr.fit(X_train_validation, y_train_validation.ravel())
print("Test accuracy logistic regression: ", round(log_regr.score(X_test, y_test),3))
print("Train accuracy logistic regression: ", round(log_regr.score(X_train_validation, y_train_validation),3))
# Out:
# Test accuracy logistic regression:  0.662
# Train accuracy logistic regression:  0.673

# %%
fig,ax=plt.subplots()
plot_conmat(y_test, log_regr.predict(X_test), 'Logistic Regression performances on test set', ax=ax)
# Out:
# <ipython-input-64-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %% [markdown]
# ### Extra Trees Classifier

# %%
from sklearn.model_selection import GridSearchCV

ext = ExtraTreesClassifier(random_state=42)

opt = GridSearchCV(estimator=ext, param_grid = param_grid, verbose = 3)

# GridSearchCV already does 5-fold cross validation by default,
# so I take both train and validation data
opt.fit(X_train_validation, y_train_validation.ravel())

# %%
opt.best_params_
# Out:
# {'bootstrap': False,
#  'max_features': 'auto',
#  'min_samples_split': 100,
#  'n_estimators': 78}

# %%
rfc= ExtraTreesClassifier(random_state=42, max_features = 'auto', min_samples_split = 100, n_estimators = 78, bootstrap = 'False')
rfc.fit(X_train_validation, y_train_validation.ravel())
# Out:
# ExtraTreesClassifier(bootstrap='False', min_samples_split=100, n_estimators=78,
#                      random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
rf_mae = mean_absolute_error(y_test, rfc.predict(X_test))
rf_mse = mean_squared_error(y_test, rfc.predict(X_test))
r2_test = rfc.score(X_test, y_test)
r2_train = rfc.score(X_train_validation, y_train_validation)

print(" ExtraTreesClassifier: ")
print(" MAE: ", round(rf_mae,3), "\n", "MSE: ", round(rf_mse,3), "\n","acc_test: ",round(r2_test,3), "\n", "acc_train: ", round(r2_train,3))
# Out:
#  ExtraTreesClassifier:
#  MAE:  0.237
#  MSE:  0.237
#  acc_test:  0.763
#  acc_train:  0.721

# %%
# Get numerical feature importances
importances = list(rfc.feature_importances_)
feature_list = list(features_train.columns)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: cyclostationary_mean_tg_4 Importance: 0.2
# Variable: cyclostationary_mean_rr_4w_3 Importance: 0.15
# Variable: cyclostationary_mean_tg_1w_3 Importance: 0.14
# Variable: cyclostationary_mean_rr_12w_1 Importance: 0.1
# Variable: cyclostationary_mean_tg_1w_4 Importance: 0.09
# Variable: cyclostationary_mean_rr_8w_0 Importance: 0.09
# Variable: cyclostationary_mean_rr_8w_2 Importance: 0.07
# Variable: cyclostationary_mean_rr_12w_0 Importance: 0.05
# Variable: cyclostationary_mean_rr_16w_2 Importance: 0.04
# Variable: cyclostationary_mean_rr_16w_1 Importance: 0.03
# Variable: cyclostationary_mean_tg_8w_0 Importance: 0.02
# Variable: cyclostationary_mean_tg_8w_3 Importance: 0.01

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
fig, ax = plt.subplots()
plt.style.use('default')
plot_conmat(y_test, rfc.predict(X_test), 'Random forest classification performances on test set', ax=ax)
plt.savefig('random_forest_classification_singletask.eps', format='eps')
# Out:
# <ipython-input-12-bc08fa3efa94>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   (df_cm.astype('float') / df_cm.sum(axis=1)[:, np.newaxis]).values.flatten()]

# %% [markdown]
# ### Feed Forward

# %%
# 10 for 0(bad), 01 for 1 (good)
y_train_ffnn = np.eye(2)[target_train['mean']]
y_validation_ffnn = np.eye(2)[target_validation['mean']]
y_test_ffnn = np.eye(2)[target_test['mean']]

# %%
tuning_model = feed_forward()

history = tuning_model.fit(X_train, y_train_ffnn, validation_data = (X_validation, y_validation_ffnn), shuffle=False, epochs=1000, verbose=0)

# %%
plt.plot(history.history['loss'], 'c', label= "loss")
plt.plot(history.history['val_loss'],'g', label= "val_loss")
plt.style.use('default')
plt.legend(loc="lower right")
plt.rcParams["figure.figsize"] = (15,5)

plt.xlabel('epochs', labelpad=10)
plt.ylabel('loss', labelpad=10)
# Out:
# Text(0, 0.5, 'loss')

# %%
y_train_val_ffnn = np.concatenate((y_train_ffnn, y_validation_ffnn))

fitting_times = 10
model = feed_forward()

test_acc = [0, 0]
train_acc = [0, 0]

for i in range(fitting_times):
  model.fit(X_train_validation, y_train_val_ffnn, shuffle=False, epochs=200, verbose=0)

  if (test_acc[1] < model.evaluate(X_test,y_test_ffnn, verbose = 0)[1]):
     test_acc = model.evaluate(X_test,y_test_ffnn, verbose = 0)
     train_acc = model.evaluate(X_train_validation,y_train_val_ffnn, verbose = 0)

# %%
print("FFNN:")
print("      ",model.metrics_names)
print("test: ", np.around(test_acc,3))
print("train: ", np.around(train_acc,3))
# Out:
# FFNN:
#        ['loss', 'accuracy']
# test:  [0.606 0.702]
# train:  [0.52  0.714]

# %% [markdown]
# ## NonLinCFA wrapper best 5

# %%
csv_path = new_features_folder + region +"_nonLinCFA_wrapper_best5_"

# %%
# extract features train/val/test sets

scaler_f = StandardScaler()

features_train = pd.read_csv(csv_path + 'train.csv')
features_valid = pd.read_csv(csv_path + 'val.csv')
features_test = pd.read_csv(csv_path + 'test.csv')

scaler_f.fit(features_train)

features_train[features_train.columns] = scaler_f.transform(features_train[features_train.columns])
features_valid[features_valid.columns] = scaler_f.transform(features_valid[features_valid.columns])
features_test[features_test.columns] = scaler_f.transform(features_test[features_test.columns])

features_train_validation = pd.concat([features_train, features_valid])

# %%
idx_dic = {}
for col in features_train.columns:
    idx_dic[col] = features_train.columns.get_loc(col)
print('\n'.join(f'{value}: {key}' for key, value in idx_dic.items()))
# Out:
# 0: cyclostationary_mean_tg_1w_0
# 1: cyclostationary_mean_rr_4w_1
# 2: cyclostationary_mean_tg_1w_2
# 3: cyclostationary_mean_tg_4w_1
# 4: cyclostationary_mean_tg_4w_0

# %%
X_train = features_train.values
X_validation = features_valid.values
X_train_validation = features_train_validation.values
X_test = features_test.values

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_regr = LogisticRegression(solver='lbfgs', random_state = 42, max_iter = 200)

log_regr.fit(X_train_validation, y_train_validation.ravel())
print("Test accuracy logistic regression: ", round(log_regr.score(X_test, y_test),3))
print("Train accuracy logistic regression: ", round(log_regr.score(X_train_validation, y_train_validation),3))
# Out:
# Test accuracy logistic regression:  0.658
# Train accuracy logistic regression:  0.585

# %% [markdown]
# ### Extra Trees Classifier

# %%
from sklearn.model_selection import GridSearchCV

ext = ExtraTreesClassifier(random_state=42)

opt = GridSearchCV(estimator=ext, param_grid = param_grid, verbose = 3)

# GridSearchCV already does 5-fold cross validation by default,
# so I take both train and validation data
opt.fit(X_train_validation, y_train_validation.ravel())
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV 1/5] END bootstrap=True, max_features=sqrt, min_samples_split=3, n_estimators

# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=121;, score=0.764 total time=   0.1s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=125;, score=0.656 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=125;, score=0.555 total time=   0.1s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=125;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=125;, score=0.711 total time=   0.1s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=125;, score=0.764 total time=   0.1s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=130;, score=0.648 total time=   0.1s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=130;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=130;, score=0.664 total time=   0.1s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=130;, score=0.719 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=130;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=134;, score=0.648 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=134;, score=0.562 total time=   0.1s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=134;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=134;, score=0.719 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=134;, score=0.764 total time=   0.1s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=138;, score=0.648 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=138;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=138;, score=0.664 total time=   0.1s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=138;, score=0.719 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=138;, score=0.764 total time=   0.1s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=142;, score=0.656 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=142;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=142;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=142;, score=0.719 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=142;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=147;, score=0.656 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=147;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=147;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=147;, score=0.711 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=147;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=151;, score=0.656 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=151;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=151;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=151;, score=0.711 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=151;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=155;, score=0.656 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=155;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=155;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=155;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=155;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=160;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=160;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=160;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=160;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=160;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=164;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=164;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=164;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=164;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=164;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=168;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=168;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=168;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=168;, score=0.711 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=168;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=172;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=172;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=172;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=172;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=172;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=177;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=177;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=177;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=177;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=177;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=181;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=181;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=181;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=181;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=181;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=185;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=185;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=185;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=185;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=185;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=190;, score=0.664 total time=   0.3s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=190;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=190;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=190;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=190;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=194;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=194;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=194;, score=0.656 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=194;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=194;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=198;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=198;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=198;, score=0.648 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=198;, score=0.695 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=198;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=202;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=202;, score=0.562 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=202;, score=0.648 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=202;, score=0.703 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=202;, score=0.764 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=207;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=207;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=207;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=207;, score=0.695 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=207;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=211;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=211;, score=0.555 total time=   0.2s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=211;, score=0.664 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=211;, score=0.695 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=211;, score=0.764 total time=   0.3s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=215;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=215;, score=0.562 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=215;, score=0.648 total time=   0.2s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=215;, score=0.695 total time=   0.3s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=215;, score=0.764 total time=   0.2s
# [CV 1/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=220;, score=0.664 total time=   0.2s
# [CV 2/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=220;, score=0.555 total time=   0.3s
# [CV 3/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=220;, score=0.656 total time=   0.3s
# [CV 4/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=220;, score=0.695 total time=   0.2s
# [CV 5/5] END bootstrap=False, max_features=sqrt, min_samples_split=100, n_estimators=220;, score=0.764 total time=   0.3s
# GridSearchCV(estimator=ExtraTreesClassifier(random_state=42),
#              param_grid={'bootstrap': [True, False],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_split': [2, 3, 5, 10, 25, 50, 100],
#                          'n_estimators': [10, 14, 18, 22, 27, 31, 35, 40, 44,
#                                           48, 52, 57, 61, 65, 70, 74, 78, 82,
#                                           87, 91, 95, 100, 104, 108, 112, 117,
#                                           121, 125, 130, 134, ...]},
#              verbose=3)

# %%
opt.best_params_
# Out:
# {'bootstrap': True,
#  'max_features': 'auto',
#  'min_samples_split': 100,
#  'n_estimators': 14}

# %%
rfc= ExtraTreesClassifier(random_state=42, max_features = 'auto', min_samples_split = 100, n_estimators = 35, bootstrap = 'True')
rfc.fit(X_train_validation, y_train_validation.ravel())
# Out:
# ExtraTreesClassifier(bootstrap='True', min_samples_split=100, n_estimators=35,
#                      random_state=42)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
rf_mae = mean_absolute_error(y_test, rfc.predict(X_test))
rf_mse = mean_squared_error(y_test, rfc.predict(X_test))
r2_test = rfc.score(X_test, y_test)
r2_train = rfc.score(X_train_validation, y_train_validation)

print(" ExtraTreesClassifier: ")
print(" MAE: ", round(rf_mae,3), "\n", "MSE: ", round(rf_mse,3), "\n","acc_test: ",round(r2_test,3), "\n", "acc_train: ", round(r2_train,3))
# Out:
#  ExtraTreesClassifier:
#  MAE:  0.206
#  MSE:  0.206
#  acc_test:  0.794
#  acc_train:  0.695

# %% [markdown]
# ### Feed Forward

# %%
# 10 for 0(bad), 01 for 1 (good)
y_train_ffnn = np.eye(2)[target_train['mean']]
y_validation_ffnn = np.eye(2)[target_validation['mean']]
y_test_ffnn = np.eye(2)[target_test['mean']]

# %%
tuning_model = feed_forward()

history = tuning_model.fit(X_train, y_train_ffnn, validation_data = (X_validation, y_validation_ffnn), shuffle=False, epochs=1000, verbose=0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-83f0aff65e49> in <module>
#       1 tuning_model = feed_forward()
#       2
# ----> 3 history = tuning_model.fit(X_train, y_train_ffnn, validation_data = (X_validation, y_validation_ffnn), shuffle=False, epochs=1000, verbose=0)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2030             self._test_counter.assign(0)
#    2031             callbacks.on_test_begin()
# -> 2032             for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2033                 self.reset_metrics()
#    2034                 with data_handler.catch_stop_iteration():
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1302         """Yields `(epoch, tf.data.Iterator)`."""
#    1303         with self._truncate_execution_to_epoch():
# -> 1304             data_iterator = iter(self._dataset)
#    1305             for epoch in range(self._initial_epoch, self._epochs):
#    1306                 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     497     if context.executing_eagerly() or ops.inside_function():
#     498       with ops.colocate_with(self._variant_tensor):
# --> 499         return iterator_ops.OwnedIterator(self)
#     500     else:
#     501       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     701             "When `dataset` is provided, `element_spec` and `components` must "
#     702             "not be specified.")
# --> 703       self._create_iterator(dataset)
#     704
#     705     self._get_next_call_count = 0
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     740             self._flat_output_types)
#     741         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 742       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     743
#     744   def __iter__(self):
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3407   if tld.is_eager:
#    3408     try:
# -> 3409       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3410         _ctx, "MakeIterator", name, dataset, iterator)
#    3411       return _result
#
# KeyboardInterrupt:

# %%
plt.plot(history.history['loss'], 'c', label= "loss")
plt.plot(history.history['val_loss'],'g', label= "val_loss")
plt.style.use('default')
plt.legend(loc="lower right")
plt.rcParams["figure.figsize"] = (15,5)

plt.xlabel('epochs', labelpad=10)
plt.ylabel('loss', labelpad=10)
# Out:
# Text(0, 0.5, 'loss')

# %%
y_train_val_ffnn = np.concatenate((y_train_ffnn, y_validation_ffnn))

fitting_times = 10
model = feed_forward()

test_acc = [0, 0]
train_acc = [0, 0]

for i in range(fitting_times):
  model.fit(X_train_validation, y_train_val_ffnn, shuffle=False, epochs=200, verbose=0)

  if (test_acc[1] < model.evaluate(X_test,y_test_ffnn, verbose = 0)[1]):
     test_acc = model.evaluate(X_test,y_test_ffnn, verbose = 0)
     train_acc = model.evaluate(X_train_validation,y_train_val_ffnn, verbose = 0)

# %%
print("FFNN:")
print("      ",model.metrics_names)
print("test: ", np.around(test_acc,3))
print("train: ", np.around(train_acc,3))
# Out:
# FFNN:
#        ['loss', 'accuracy']
# test:  [0.641 0.671]
# train:  [0.512 0.731]
